# %% [markdown]
# # Inference of the Speech-to-Speech Translation model
#
# Inference can be done on both CPU and GPU, but GPU is recommended.

# %%
# !pip install git+https://github.com/speechbrain/speechbrain.git@develop
# !pip install transformers huggingface_hub

# %%
import torch
import torchaudio
from inference import S2STInference
from speechbrain.inference.vocoders import UnitHIFIGAN


device = 'cuda' if torch.cuda.is_available() else 'cpu'

s2st = S2STInference.from_hparams(source="sinarashidi/s2st_fa-en_augmented", savedir="tmpdir_s2st", run_opts={'device': device})
hifi_gan_unit = UnitHIFIGAN.from_hparams(source="sinarashidi/unit_hifigan_ljspeech", savedir="tmpdir_vocoder", run_opts={'device': device})

# %%
codes = s2st.translate_file("sinarashidi/s2st_fa-en_augmented/audio/test2.mp3")
codes = torch.IntTensor(codes)

waveforms = hifi_gan_unit.decode_unit(codes)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 codes = s2st.translate_file("sinarashidi/s2st_fa-en_augmented/audio/test2.mp3")
#       2 codes = torch.IntTensor(codes)
#       4 waveforms = hifi_gan_unit.decode_unit(codes)
#
# File ~/projects/thesis_code/inference.py:16, in S2STInference.translate_file(self, path)
#      15 def translate_file(self, path):
# ---> 16     audio = self.load_audio(path)
#      17     audio = audio.to(self.device)
#      19     batch = audio.unsqueeze(0)
#
# File ~/projects/thesis_code/.venv/lib/python3.10/site-packages/speechbrain/inference/interfaces.py:286, in Pretrained.load_audio(self, path, savedir)
#     276 """Load an audio file with this model's input spec
#     277
#     278 When using a speech model, it is important to use the same type of data,
#    (...)
#     283 The path can be a local path, a web url, or a link to a huggingface repo.
#     284 """
#     285 source, fl = split_path(path)
# --> 286 path = fetch(fl, source=source, savedir=savedir)
#     287 signal, sr = torchaudio.load(str(path), channels_first=False)
#     288 return self.audio_normalizer(signal, sr)
#
# File ~/projects/thesis_code/.venv/lib/python3.10/site-packages/speechbrain/utils/fetching.py:160, in fetch(filename, source, savedir, overwrite, save_filename, use_auth_token, revision, huggingface_cache_dir)
#     158 logger.info(MSG)
#     159 try:
# --> 160     fetched_file = huggingface_hub.hf_hub_download(
#     161         repo_id=source,
#     162         filename=filename,
#     163         use_auth_token=use_auth_token,
#     164         revision=revision,
#     165         cache_dir=huggingface_cache_dir,
#     166     )
#     167     logger.info(f"HF fetch: {fetched_file}")
#     168 except HTTPError as e:
#
# File ~/projects/thesis_code/.venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     101 for arg_name, arg_value in chain(
#     102     zip(signature.parameters, args),  # Args values
#     103     kwargs.items(),  # Kwargs values
#     104 ):
#     105     if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106         validate_repo_id(arg_value)
#     108     elif arg_name == "token" and arg_value is not None:
#     109         has_token = True
#
# File ~/projects/thesis_code/.venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:154, in validate_repo_id(repo_id)
#     151     raise HFValidationError(f"Repo id must be a string, not {type(repo_id)}: '{repo_id}'.")
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#     160     raise HFValidationError(
#     161         "Repo id must use alphanumeric chars or '-', '_', '.', '--' and '..' are"
#     162         " forbidden, '-' and '.' cannot start or end the name, max length is 96:"
#     163         f" '{repo_id}'."
#     164     )
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'sinarashidi/s2st_fa-en_augmented/audio'. Use `repo_type` argument if needed.

# %%
from IPython.display import Audio, display


# torchaudio.save(f"translated_file.wav",waveforms.squeeze(1).cpu(), 16000)
display(Audio(waveforms.cpu(), rate=16000))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
